# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Categorical Plots

# %%
sns.countplot(x = "sex", data = df, hue='smoker')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = "children", data = df,hue="smoker")
# Out:
# <AxesSubplot:xlabel='children', ylabel='count'>

# %% [markdown]
# Most of the people, do not have children and with increase in no. of children, count of smokers decreases

# %% [markdown]
# From the above graph it is clear that smokers has more charges than non-smokers for both the genders

# %%
sns.countplot(x = "region", data = df, hue='smoker')
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %% [markdown]
# Southeast people smoke more

# %%
plt.figure(figsize=(15,9))
sns.boxplot(y="smoker", x="charges", data =  df , orient="h",hue='sex' )
# Out:
# <AxesSubplot:xlabel='charges', ylabel='smoker'>

# %% [markdown]
# # Distribution Plots

# %%
plt.figure(figsize=(15,9))
sns.distplot(df["age"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.lmplot(x="age", y="charges", hue="smoker", data=df, size = 7)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(15,9))
sns.distplot(df["bmi"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
plt.figure(figsize=(15,9))
ax = sns.scatterplot(x='bmi',y='charges',data=df,hue='smoker')

# %% [markdown]
# # Matrix Plot

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Label Encoding

# %%
print(df['sex'].value_counts())
print(df['smoker'].value_counts())
print(df['region'].value_counts())
# Out:
# male      676
# female    662
# Name: sex, dtype: int64
# no     1064
# yes     274
# Name: smoker, dtype: int64
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# age - std scaler
# sex - label encoding
# bmi - std scaler
# children - normal
# smoker - label
# region - hot encoding but used label encoding 
# charges - target

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df["sex"] = le.fit_transform(df["sex"])

# %%
df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
print(df['sex'].value_counts())
# Out:
# 1    676
# 0    662
# Name: sex, dtype: int64

# %%
df["smoker"] = le.fit_transform(df["smoker"])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
print(df['smoker'].value_counts())
# Out:
# 0    1064
# 1     274
# Name: smoker, dtype: int64

# %%
print(df['region'].value_counts())
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
d = le.fit_transform(df["region"])

# %%
dd = pd.DataFrame(d)

# %%
dd.value_counts()
# Out:
# 2    364
# 1    325
# 3    325
# 0    324
# dtype: int64

# %%
df['region'] = d

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %% [markdown]
# # Modelling

# %%
x = df[['age', 'sex', 'bmi','children', 'smoker','region']]
y = df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train
# Out:
#       age  sex     bmi  children  smoker  region
# 468    28    0  24.320         1       0       0
# 643    23    0  34.960         3       0       1
# 1296   18    1  26.125         0       0       0
# 931    39    0  32.500         1       0       3
# 1110   54    0  32.300         1       0       0
# ...   ...  ...     ...       ...     ...     ...
# 575    58    0  27.170         0       0       1
# 973    19    0  40.500         0       0       3
# 75     57    1  34.010         0       0       1
# 599    52    0  37.525         2       0       1
# 863    36    0  19.855         0       0       0
#
# [802 rows x 6 columns]

# %%
y_train
# Out:
# 468     23288.92840
# 643      4466.62140
# 1296     1708.92575
# 931      6238.29800
# 1110    11512.40500
#            ...
# 575     12222.89830
# 973      1759.33800
# 75      11356.66090
# 599     33471.97189
# 863      5458.04645
# Name: charges, Length: 802, dtype: float64

# %%
lm.predict(x_test[])

# %%
predictions = lm.predict(x_test)

# %%
plt.scatter(y_test,predictions)

# %%
print(predictions[0:5]) 
print(y_test[0:5])
# Out:
# [11195.42951446  3320.71771472 10573.94458221 27473.59767071
#   6540.68715994]
# 44       6079.67150
# 134      2457.21115
# 980     25517.11363
# 618     34439.85590
# 1238     6985.50695
# Name: charges, dtype: float64

# %%
df_final = pd.DataFrame({'Predicted':predictions,'Actual':y_test})

# %%
df_final = df_final.reset_index()

# %%
df_final = df_final.drop(['index'],axis=1)

# %%
fig= plt.figure(figsize=(16,8))
plt.plot(df_final[:50])
plt.legend(['Real','Prediction'])

# %%
fig= plt.figure(figsize=(16,8))
sns.jointplot(x='Actual',y='Predicted',data=df_final,kind='reg',)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 3920.536943887807
# MSE: 31667189.325165786
# RMSE: 5627.360777946069

# %%
import pickle

# %%
with open("model.pkl",'wb') as f:
    pickle.dump(lm,f)
